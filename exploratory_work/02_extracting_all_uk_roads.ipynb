# %%
import requests

# Define the SPARQL endpoint and query
url = 'https://query.wikidata.org/sparql'
query = """
SELECT ?road ?roadLabel ?kmlTemplate
WHERE {
  # ?road wdt:P16 wd:Q387692;   
        wdt:P3096 ?kmlTemplate.  # P3096 is the property for KML files
  
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
"""

# Make the request
headers = {
    'Accept': 'application/sparql-results+json'
}
response = requests.get(url, headers=headers, params={'query': query})

# Check if the request was successful
if response.status_code != 200:
    raise Exception(f"Query failed with status code {response.status_code}")

# Convert the response to JSON
results = response.json()

# Extract the bindings from the results
bindings = results['results']['bindings']

# Extract KML template URLs and their labels
kml_templates = []
for item in bindings:
    kml_template = item['kmlTemplate']['value']
    road_label = item['roadLabel']['value']
    kml_templates.append((road_label, kml_template))

# Print the KML templates
for road, template in kml_templates:
    print(f"{road}: {template}")
# Out:
# M25 motorway: http://www.wikidata.org/entity/Q26326887
# M1 motorway: http://www.wikidata.org/entity/Q26330001
# M67 motorway: http://www.wikidata.org/entity/Q26329958
# A1 road: http://www.wikidata.org/entity/Q26330216
# A38(M) motorway: http://www.wikidata.org/entity/Q26330136
# A91 road: http://www.wikidata.org/entity/Q26360850
# M6 Toll: http://www.wikidata.org/entity/Q26330022
# M80 motorway: http://www.wikidata.org/entity/Q26330113
# M18 motorway: http://www.wikidata.org/entity/Q26330034
# M90 motorway: http://www.wikidata.org/entity/Q26330116
# M27 motorway: http://www.wikidata.org/entity/Q26330048
# A823(M) motorway: http://www.wikidata.org/entity/Q26342825
# M20 motorway: http://www.wikidata.org/entity/Q26330039
# M50 motorway: http://www.wikidata.org/entity/Q26330072
# M898 motorway: http://www.wikidata.org/entity/Q26342761
# A2 road: http://www.wikidata.org/entity/Q26330219
# M2 motorway: http://www.wikidata.org/entity/Q26330005
# M48 motorway: http://www.wikidata.org/entity/Q26330066
# M42 motorway: http://www.wikidata.org/entity/Q26330060
# M9 motorway: http://www.wikidata.org/entity/Q26330028
# M271 motorway: http://www.wikidata.org/entity/Q26330127
# M11 motorway: http://www.wikidata.org/entity/Q26330031
# M23 motorway: http://www.wikidata.org/entity/Q26330043
# M40 motorway: http://www.wikidata.org/entity/Q26330057
# M60 motorway: http://www.wikidata.org/entity/Q26330090
# M4 motorway: http://www.wikidata.org/entity/Q26330011
# M3 motorway: http://www.wikidata.org/entity/Q26330008
# M32 motorway: http://www.wikidata.org/entity/Q26330053
# M5 motorway: http://www.wikidata.org/entity/Q26330014
# M180 motorway: http://www.wikidata.org/entity/Q26330122
# M181 motorway: http://www.wikidata.org/entity/Q26330125
# M26 motorway: http://www.wikidata.org/entity/Q26330045
# M45 motorway: http://www.wikidata.org/entity/Q26330063
# M62 motorway: http://www.wikidata.org/entity/Q26329767
# M6 motorway: http://www.wikidata.org/entity/Q26330018
# M8 motorway: http://www.wikidata.org/entity/Q26330025
# A516 road: http://www.wikidata.org/entity/Q26373087
# A523 road: http://www.wikidata.org/entity/Q26348907
# A52 road: http://www.wikidata.org/entity/Q26331202
# A53 road: http://www.wikidata.org/entity/Q26370752
# A54 road: http://www.wikidata.org/entity/Q26371558
# A56 road: http://www.wikidata.org/entity/Q26348825
# A592 road: http://www.wikidata.org/entity/Q26348972
# A6030 road: http://www.wikidata.org/entity/Q26349218
# A6055 road: http://www.wikidata.org/entity/Q26349279
# A601(M) motorway: http://www.wikidata.org/entity/Q26342811
# A60 road: http://www.wikidata.org/entity/Q26348852
# A6182 road: http://www.wikidata.org/entity/Q26329955
# A628 road: http://www.wikidata.org/entity/Q26341609
# A627(M) motorway: http://www.wikidata.org/entity/Q26342818
# A661 road: http://www.wikidata.org/entity/Q26348914
# A697 road: http://www.wikidata.org/entity/Q26341926
# A6 road: http://www.wikidata.org/entity/Q26330227
# A7 road: http://www.wikidata.org/entity/Q26330228
# A8 road: http://www.wikidata.org/entity/Q26330231
# B5289 road: http://www.wikidata.org/entity/Q26349406
# B5470 road: http://www.wikidata.org/entity/Q26339985
# M275 motorway: http://www.wikidata.org/entity/Q26330130
# M49 motorway: http://www.wikidata.org/entity/Q26330068
# M54 motorway: http://www.wikidata.org/entity/Q26341957
# M602 motorway: http://www.wikidata.org/entity/Q26342736
# M606 motorway: http://www.wikidata.org/entity/Q26342743
# M61 motorway: http://www.wikidata.org/entity/Q26330092
# M621 motorway: http://www.wikidata.org/entity/Q26342749
# M77 motorway: http://www.wikidata.org/entity/Q26330111
# M876 motorway: http://www.wikidata.org/entity/Q26330134
# Mancunian Way: http://www.wikidata.org/entity/Q26330139
# A1159 road: http://www.wikidata.org/entity/Q26349111
# A6079 road: http://www.wikidata.org/entity/Q26349382
# A624 road: http://www.wikidata.org/entity/Q26341590
# B4574 road: http://www.wikidata.org/entity/Q26349398
# A15 road: http://www.wikidata.org/entity/Q26330246

# %%
import json

# Process each KML template to extract Wikipedia links
def get_wiki_link(url):
    # Fetch the KML template content
    kml_response = requests.get(url)
    entity_name = template.split("/")[4]
    
    if kml_response.status_code == 200:
        kml_content = json.loads(kml_response.text)
        wikipedia_link = kml_content['entities'][entity_name]['sitelinks']['enwiki']['url']
        
        return wikipedia_link

# %%
from bs4 import BeautifulSoup
import requests
 
def extract_kml(url):

    # call get method to request that page
    page = requests.get(url)
    
    # with the help of beautifulSoup and html parser create soup
    soup = BeautifulSoup(page.content, "html.parser")
    
    mydivs = soup.find("div", {"class": "mw-content-ltr mw-parser-output"})

    road_name = url.split("/")[5]

    if mydivs.text:
        with open(f'../data/roads/{road_name}.kml', 'w', encoding='utf-8') as file:
            file.write(mydivs.text)

# %%
for road, template in kml_templates:
    try:
        url = get_wiki_link(template)
        extract_kml(url)
    except:
        pass
